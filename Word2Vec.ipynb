# %% [markdown]
# ### Word2Vec Implementation

# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/24.0 MB 12.2 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/24.0 MB 10.1 MB/s eta 0:00:02
#    --------- ------------------------------ 5.5/24.0 MB 8.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 6.8/24.0 MB 8.1 MB/s eta 0:00:03
#    ------------- -------------------------- 8.4/24.0 MB 8.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.0/24.0 MB 8.0 MB/s eta 0:00:02
#    -------------------- ------------------- 12.1/24.0 MB 8.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.2/24.0 MB 8.3 MB/s eta 0:00:02
#    -------------------------- ------------- 16.0/24.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.3/24.0 MB 8.3 MB/s eta 0:00:01
#    ------------------------------- -------- 18.9/24.0 MB 8.2 MB/s eta 0:00:01
# ...

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

dataset = api.load('word2vec-google-news-300')
model = dataset['king']  # it gives the vector for 'king'

# %%
model
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
dataset.similar_by_word('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]

# %%
dataset.most_similar('Travel')
# Out:
# [('travel', 0.6577276587486267),
#  ('Adventure_Travel', 0.636359453201294),
#  ('Travel_Agent', 0.608870804309845),
#  ('Aol_Autos', 0.5961860418319702),
#  ('Destinations', 0.5935966968536377),
#  ('Vacations', 0.5759146213531494),
#  ('Vantage_Deluxe', 0.573976993560791),
#  ('Travel_Destinations', 0.5731626152992249),
#  ('Travel_Agents', 0.5724309086799622),
#  ('Escorted_Tours', 0.557145893573761)]

# %%
dataset.similar_by_word('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
## similarity between words
dataset.similarity('happy', 'joyful')
# Out:
# 0.42381963

# %%
vector = dataset['Man'] + dataset['King'] - dataset['Queen']

# %%
vector
# Out:
# array([ 3.20709229e-01,  2.80883789e-01, -2.44140625e-02, -1.07421875e-01,
#         1.64062500e-01,  8.27941895e-02, -4.35791016e-02,  1.37695312e-01,
#         6.56250000e-01, -6.35986328e-02, -1.97265625e-01,  1.76269531e-01,
#        -2.40234375e-01,  5.37109375e-03, -2.23388672e-01, -1.35742188e-01,
#        -3.01757812e-01, -3.66210938e-03, -3.05175781e-01,  2.39257812e-02,
#        -2.94494629e-02, -4.88281250e-04,  5.08544922e-01,  2.11914062e-01,
#        -1.62353516e-02, -2.05078125e-01, -1.32324219e-01,  1.84570312e-01,
#         2.50976562e-01,  9.42382812e-02, -2.41699219e-02,  1.29394531e-01,
#         1.56250000e-02, -9.49707031e-02, -3.27148438e-01,  4.08203125e-01,
#         6.05468750e-02, -4.75769043e-01,  1.43066406e-01,  2.68188477e-01,
#         1.51855469e-01,  5.85937500e-03,  2.81738281e-01,  2.59521484e-01,
#        -2.20947266e-01, -2.22167969e-01,  1.61193848e-01,  2.97851562e-02,
# ...

# %%
dataset.most_similar([vector])
# Out:
# [('Man', 0.7784375548362732),
#  ('Woman', 0.4340570569038391),
#  ('Suspect', 0.43192678689956665),
#  ('Deliveryman', 0.4289354383945465),
#  ('Boy', 0.42689043283462524),
#  ('man', 0.42369744181632996),
#  ('Son', 0.40698570013046265),
#  ('Counterfeiter', 0.404392808675766),
#  ('depicts_Michelangelo_Creation', 0.4020105004310608),
#  ('Bondsman', 0.3945557773113251)]
